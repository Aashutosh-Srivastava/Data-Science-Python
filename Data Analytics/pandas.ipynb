# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### what you need to learn
# - loading data()
# - selection
#    - cols
#    - rows
# - manipulation
#     - add col
#     - remove col
#     - rename col
#     - change data type
#     - del data
#     - remove duplications
#     - sort
#     - group
#     - merge
#     - merge
#     - pivot
# - visualisation
#      - line plot
#      - bar plot
#      - histogram
#      - box plot
#      - scatter plot
#      - heatmap
#      - pie chart
#      - word cloud

# %%
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# -analysis
#   - univariate
#   - bi-variate
#   - multivariate

# %% [markdown]
# - Loading data
#    - custom data
#    - excel data
#    - csv/json/etc
#    - database

# %%
student = {'name':['ram','raj','sneha','raju'],
           'college':['msv','kpc','srm','arm'],
           'dob':['12 jan','23feb','3 march','23dec']}
sdf = pd.DataFrame(student)
sdf
# Out:
#     name college      dob
# 0    ram     msv   12 jan
# 1    raj     kpc    23feb
# 2  sneha     srm  3 march
# 3   raju     arm    23dec

# %%
data = pd.read_excel('C:/Users/ASHU/Documents/fruits.xlsx')
data
# Out:
#      item  amount
# 0   apple     100
# 1  banana     200
# 2  mango      150
# 3  cherry     300

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   item    4 non-null      object
#  1   amount  4 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes

# %%
data.columns.tolist()
# Out:
# ['item', 'amount']

# %%
data['item']
# Out:
# 0     apple
# 1    banana
# 2    mango
# 3    cherry
# Name: item, dtype: object

# %%
data.amount
# Out:
# 0    100
# 1    200
# 2    150
# 3    300
# Name: amount, dtype: int64

# %%
# data[collist]

data[['item','amount']]
# Out:
#      item  amount
# 0   apple     100
# 1  banana     200
# 2  mango      150
# 3  cherry     300

# %%
data['amount'] * data['item']
# Out:
# 0    appleappleappleappleappleappleappleappleapplea...
# 1    bananabananabananabananabananabananabananabana...
# 2    mango mango mango mango mango mango mango mang...
# 3    cherrycherrycherrycherrycherrycherrycherrycher...
# dtype: object

# %%
# data['mew_col'] = expression
data['0new_add'] = data['amount'] * data['item']
data
# Out:
#      item  amount                                           0new_add
# 0   apple     100  appleappleappleappleappleappleappleappleapplea...
# 1  banana     200  bananabananabananabananabananabananabananabana...
# 2  mango      150  mango mango mango mango mango mango mango mang...
# 3  cherry     300  cherrycherrycherrycherrycherrycherrycherrycher...

# %%
data.iloc[0]
# Out:
# item                                                    apple
# amount                                                    100
# 0new_add    appleappleappleappleappleappleappleappleapplea...
# Name: 0, dtype: object

# %%
student
# Out:
# {'name': ['ram', 'raj', 'sneha', 'raju'],
#  'college': ['msv', 'kpc', 'srm', 'arm'],
#  'dob': ['12 jan', '23feb', '3 march', '23dec']}

# %%
sdf
# Out:
#     name college      dob
# 0    ram     msv   12 jan
# 1    raj     kpc    23feb
# 2  sneha     srm  3 march
# 3   raju     arm    23dec

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.drop(columns='body_mass_g')        #removing cols
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#         sex
# 0      Male
# 1    Female
# 2    Female
# 3       NaN
# 4    Female
# ...

# %%
penguins.drop(columns=['island','body_mass_g'])
# Out:
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm     sex
# 0    Adelie            39.1           18.7              181.0    Male
# 1    Adelie            39.5           17.4              186.0  Female
# 2    Adelie            40.3           18.0              195.0  Female
# 3    Adelie             NaN            NaN                NaN     NaN
# 4    Adelie            36.7           19.3              193.0  Female
# ..      ...             ...            ...                ...     ...
# 339  Gentoo             NaN            NaN                NaN     NaN
# 340  Gentoo            46.8           14.3              215.0  Female
# 341  Gentoo            50.4           15.7              222.0    Male
# 342  Gentoo            45.2           14.8              212.0  Female
# 343  Gentoo            49.9           16.1              213.0    Male
#
# [344 rows x 5 columns]

# %%
penguins.drop(index=2)   #will drop 3rs row
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.drop(index=[1,2,3,4,5])   #drop multiple rows
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 6         3625.0  Female
# ...

# %%
penguins.drop(index = range(10))  #another method to drop rows
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 12   Adelie  Torgersen            41.1           17.6              182.0
# 13   Adelie  Torgersen            38.6           21.2              191.0
# 14   Adelie  Torgersen            34.6           21.1              198.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 10        3300.0     NaN
# 11        3700.0     NaN
# ...

# %%
np.nan
# Out:
# nan

# %% [markdown]
# find the missing values if each columns

# %%
penguins.isnull().sum().plot(kind='bar')   #overall null values evaluation
# Out:
# <Axes: >

# %%
sns.heatmap(penguins.isnull(),cbar=False)    #column wise null value evaluation
# Out:
# <Axes: >

# %% [markdown]
# removing missing values (null values)

# %%
penguins.dropna()  #drop rows with null values
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# penguins.shape

penguins.dropna().shape
# Out:
# (333, 7)

# %%
penguins.dropna(inplace = True)
print(penguins.shape)
# Out:
# (333, 7)

# %%
penguins.drop_duplicates(subset= ['species'])    #removing duplicates values
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 152  Chinstrap      Dream            46.5           17.9              192.0
# 220     Gentoo     Biscoe            46.1           13.2              211.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 152       3500.0  Female
# 220       4500.0  Female

# %%
penguins.sort_values(by =['sex','island'], ascending =False)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 13   Adelie  Torgersen            38.6           21.2              191.0
# 14   Adelie  Torgersen            34.6           21.1              198.0
# ..      ...        ...             ...            ...                ...
# 332  Gentoo     Biscoe            43.5           15.2              213.0
# 334  Gentoo     Biscoe            46.2           14.1              217.0
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 5         3650.0    Male
# ...

# %%
penguins.sort_values?
# Out:
# Signature:
# penguins.sort_values(
#     by: 'IndexLabel',
#     *,
#     axis: 'Axis' = 0,
#     ascending: 'bool | list[bool] | tuple[bool, ...]' = True,
#     inplace: 'bool' = False,
#     kind: 'SortKind' = 'quicksort',
#     na_position: 'str' = 'last',
#     ignore_index: 'bool' = False,
#     key: 'ValueKeyFunc | None' = None,
# ) -> 'DataFrame | None'
# Docstring:
# Sort by the values along either axis.
#
# Parameters
# ----------
# by : str or list of str
#     Name or list of names to sort by.
#
#     - if `axis` is 0 or `'index'` then `by` may contain index
#       levels and/or column labels.
#     - if `axis` is 1 or `'columns'` then `by` may contain column
#       levels and/or index labels.
# axis : "{0 or 'index', 1 or 'columns'}", default 0
#      Axis to be sorted.
# ascending : bool or list of bool, default True
#      Sort ascending vs. descending. Specify list for multiple sort
#      orders.  If this is a list of bools, must match the length of
#      the by.
# ...

# %% [markdown]
# - Data types in pandas
#     - int
#     - float
#     - str        (not understood by pandas)
#     - bool
#     - object    (default data type)
#     - datetime
#     - category

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.8+ KB

# %%
penguins.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
penguins.select_dtypes(include='number')
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0              39.1           18.7              181.0       3750.0
# 1              39.5           17.4              186.0       3800.0
# 2              40.3           18.0              195.0       3250.0
# 4              36.7           19.3              193.0       3450.0
# 5              39.3           20.6              190.0       3650.0
# ..              ...            ...                ...          ...
# 338            47.2           13.7              214.0       4925.0
# 340            46.8           14.3              215.0       4850.0
# 341            50.4           15.7              222.0       5750.0
# 342            45.2           14.8              212.0       5200.0
# 343            49.9           16.1              213.0       5400.0
#
# [333 rows x 4 columns]

# %%
penguins.select_dtypes(exclude = 'number')  #exclude numeric datatype
# Out:
#     species     island     sex
# 0    Adelie  Torgersen    Male
# 1    Adelie  Torgersen  Female
# 2    Adelie  Torgersen  Female
# 4    Adelie  Torgersen  Female
# 5    Adelie  Torgersen    Male
# ..      ...        ...     ...
# 338  Gentoo     Biscoe  Female
# 340  Gentoo     Biscoe  Female
# 341  Gentoo     Biscoe    Male
# 342  Gentoo     Biscoe  Female
# 343  Gentoo     Biscoe    Male
#
# [333 rows x 3 columns]

# %%
penguins['island'].astype('category')
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 4      Torgersen
# 5      Torgersen
#          ...
# 338       Biscoe
# 340       Biscoe
# 341       Biscoe
# 342       Biscoe
# 343       Biscoe
# Name: island, Length: 333, dtype: category
# Categories (3, object): ['Biscoe', 'Dream', 'Torgersen']

# %%
penguins['island'] = penguins['island'].astype('category')

# %%
penguins.dtypes
# Out:
# species                object
# island               category
# bill_length_mm        float64
# bill_depth_mm         float64
# flipper_length_mm     float64
# body_mass_g           float64
# sex                    object
# dtype: object

# %% [markdown]
# - simple visualisation    (uni-variate)
#     - for numerical data
#         - line plot -> '.plot()'
#         - histogram -> '.hist()'
#         - bar plot  ->  'plot(kind='bar')'
#         - area plot  ->  'plot(kind='area')'
#         - box plot  ->   'plot(kind = 'box')
#     - for categorical data
#         - pie chart -> 'pie()'
# ------------------------------------------------------------

# %%
penguins['bill_depth_mm'].hist()
# Out:
# <Axes: >

# %%
penguins['body_mass_g'].plot(kind='area',figsize = (15,5))
# Out:
# <Axes: >

# %%
penguins["bill_depth_mm"].plot(kind ='box')
# Out:
# <Axes: >

# %% [markdown]
# Comparing univariate values

# %%
penguins[['bill_depth_mm','body_mass_g']].hist()
# Out:
# array([[<Axes: title={'center': 'bill_depth_mm'}>,
#         <Axes: title={'center': 'body_mass_g'}>]], dtype=object)

# %%
penguins[['bill_depth_mm','body_mass_g']].plot(layout=(2,1),subplots=True)
# Out:
# array([[<Axes: >],
#        [<Axes: >]], dtype=object)

# %% [markdown]
# ### The Power of seaborn

# %%
sns.displot(data = penguins,x='bill_depth_mm')

# %%
sns.displot(data = penguins,x='bill_depth_mm',hue = 'island')

# %%
penguins['island'].value_counts(0)
# Out:
# island
# Biscoe       163
# Dream        123
# Torgersen     47
# Name: count, dtype: int64

# %%
penguins['island'].value_counts(0).plot(kind='bar')
# Out:
# <Axes: xlabel='island'>

# %%
sns.countplot(data = penguins,x='island',hue = 'species')
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %% [markdown]
# - bi variate anaysis
#     - scatter plot
#     - violin plot
#     - pair plot

# %%
sns.scatterplot(data= penguins, x='bill_length_mm',y='bill_length_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_length_mm'>

# %%
sns.scatterplot(data= penguins, x='bill_length_mm',y='bill_length_mm',hue = 'island')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_length_mm'>

# %%
tips = sns.load_dataset("tips")
sns.relplot(data=tips, x="total_bill", y="tip")

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="smoker")

# %%
sns.relplot(
    data=tips,
    x="total_bill", y="tip", hue="smoker", style="smoker"
)

# %%
sns.relplot(
    data=tips,
    x="total_bill", y="tip", hue="smoker", style="time",
)

# %%
dowjones = sns.load_dataset("dowjones")
sns.relplot(data=dowjones, x="Date", y="Price", kind="line")

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(data=fmri, x="timepoint", y="signal", kind="line")

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", errorbar=None,
)

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal",
    estimator=None,
)
